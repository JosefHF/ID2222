# %%
import random  
import operator
M = 100#25571
t=0
tau=0
tau_count = {}
S = set()

def flippedBiasedCoin(M,t):
    hot=random.choices(population = ["h","t"], weights=[M/t,1-(M/t)])
#     if hot[0] == "h":
#         print(M,t)
    return hot[0]          
            
            
def sampleEdge(edge,t,M):
    if t<=M:
        return True
    elif flippedBiasedCoin(M,t)=="h":
        random_edge = random.sample(S,1)[0]
        S.remove(random_edge)
        #updateCounters(operator.sub, random_edge)
        return True
    else:
        return False

def updateCounters(operator,edge):
    global tau, S
    u=edge[0]
    v=edge[1]
    #u = edge.split("-")[0]
    #v = edge.split("-")[1]
    nu = set()
    nv = set()
    #Alla neighbours
    for elem in S:
        if u == elem[0]:
            nu.add(elem[1])
        if u == elem[1]:
            nu.add(elem[0])
        if v == elem[0]:
            nv.add(elem[1])
        if v == elem[1]:
            nv.add(elem[0])
    #Loopa igenom alla snitten av neighbours till u och v        
    #print(nu.intersection(nv))
    for c in nu.intersection(nv): 
        n = (t-1)*(t-2)
        n = n/(M/(M-1))
        n_t = max(1,n)
        print(n_t)
        tau = operator(tau,n_t)
        tau_count[c] = operator(int(tau_count.get(c) or 0),n_t)
        tau_count[u] = operator(int(tau_count.get(u) or 0),n_t)
        tau_count[v] = operator(int(tau_count.get(v) or 0),n_t)
        
    #print(tau)
    
with open("email-Eu-core.txt") as file:
    for line in file:
        if "#" in line:
            continue
        else:
            edge = tuple(line.replace("\n","").split(" "))
            if int(edge[0]) > int(edge[1]):
                edge = tuple([edge[1],edge[0]])
                
            if edge in S or edge[0] == edge[1]:
                continue
            else:
                t+=1
                if t % 1000 == 0:
                    print("t:",t,"tau:", tau)
                updateCounters(operator.add,edge)
                if sampleEdge(edge,t,M):
                    S.add(edge)
                    
    eps = (t*(t-1)*(t-2))/(M*(M-1)*(M-2))
    if eps < 1:
        eps = 1
print("The number of triangles are:", tau * eps)
# Out:
# t: 1000 tau: 2865826.2600000002
# t: 2000 tau: 14883204.600000001
# t: 3000 tau: 55536281.46
# t: 4000 tau: 93744319.68
# t: 5000 tau: 111748420.08000001
# t: 6000 tau: 336974829.84000003
# t: 7000 tau: 495485074.26
# t: 8000 tau: 495485074.26
# t: 9000 tau: 646454015.4599999
# t: 10000 tau: 731738795.04
# t: 11000 tau: 842629162.3199999
# t: 12000 tau: 842629162.3199999
# t: 13000 tau: 842629162.3199999
# t: 14000 tau: 1035271826.8199999
# t: 15000 tau: 1035271826.8199999
# t: 16000 tau: 1035271826.8199999
# t: 17000 tau: 1308849171.3
# t: 18000 tau: 1308849171.3
# t: 19000 tau: 1308849171.3
# t: 20000 tau: 1308849171.3
# t: 21000 tau: 1308849171.3
# t: 22000 tau: 1308849171.3
# t: 23000 tau: 1308849171.3
# t: 24000 tau: 1308849171.3
# t: 25000 tau: 1894035850.7399998
# The number of triangles are: 3.2637667095067604e+16

# %%
t
# Out:
# 16064

# %%
import random  
import operator
M = 1000000
t=0
tau=0
tau_count = {}
S = set()

def flippedBiasedCoin(M,t):
    hot=random.choices(population = ["h","t"], weights=[M/t,1-(M/t)])
#     if hot[0] == "h":
#         print(M,t)
    return hot[0]          
            
            
def sampleEdge(edge,t,M):
    if t<=M:
        return True
    elif flippedBiasedCoin(M,t)=="h":
        random_edge = random.sample(S,1)[0]
        S.remove(random_edge)
        updateCounters(operator.sub, random_edge)
        return True
    else:
        return False

def updateCounters(operator,edge):
    global tau, S
    u=edge[0]
    v=edge[1]
    #u = edge.split("-")[0]
    #v = edge.split("-")[1]
    nu = set()
    nv = set()
    #Alla neighbours
    for elem in S:
        if u == elem[0]:
            nu.add(elem[1])
        if u == elem[1]:
            nu.add(elem[0])
        if v == elem[0]:
            nv.add(elem[1])
        if v == elem[1]:
            nv.add(elem[0])
    #Loopa igenom alla snitten av neighbours till u och v        
    #print(nu.intersection(nv))
    for c in nu.intersection(nv):
        tau = operator(tau,1)
        tau_count[c] = operator(int(tau_count.get(c) or 0),1)
        tau_count[u] = operator(int(tau_count.get(u) or 0),1)
        tau_count[v] = operator(int(tau_count.get(v) or 0),1)
        
    #print(tau)
    
with open("email-Eu-core.txt") as file:
    for line in file:
        if "#" in line:
            continue
        else:
            edge = tuple(line.replace("\n","").split(" "))
            if int(edge[0]) > int(edge[1]):
                edge = tuple([edge[1],edge[0]])
            t+=1
            if t % 1000 == 0:
                print("t:",t,"tau:", tau)
                    
            if edge in S or edge[0] == edge[1]:
                continue
            else:
                if sampleEdge(edge,t,M):
                    S.add(edge)
                    updateCounters(operator.add,edge)
    eps = (t*(t-1)*(t-2))/(M*(M-1)*(M-2))
    if eps < 1:
        eps = 1
print("The number of triangles are:", tau * eps)
# Out:
# t: 1000 tau: 197
# t: 2000 tau: 787
# t: 3000 tau: 1619
# t: 4000 tau: 2628
# t: 5000 tau: 4118
# t: 6000 tau: 5911
# t: 7000 tau: 7937
# t: 8000 tau: 10834
# t: 9000 tau: 13790
# t: 10000 tau: 16881
# t: 11000 tau: 20491
# t: 12000 tau: 24017
# t: 13000 tau: 27803
# t: 14000 tau: 32850
# t: 15000 tau: 37993
# t: 16000 tau: 43922
# t: 17000 tau: 49210
# t: 18000 tau: 54249
# t: 19000 tau: 60689
# t: 20000 tau: 67417
# t: 21000 tau: 73489
# t: 22000 tau: 79981
# t: 23000 tau: 85951
# t: 24000 tau: 93294
# t: 25000 tau: 100904
# The number of triangles are: 105461
